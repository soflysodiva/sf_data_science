# %%
import pandas as pd

melb_data_fe = pd.read_csv('data/melb_data_fe.csv')
melb_data_fe.head()
# Out:
#        Suburb  Rooms   Type      Price Method SellerG        Date  Distance  \
# 0  Abbotsford      2  house  1480000.0      S  Biggin  2016-03-12       2.5
# 1  Abbotsford      2  house  1035000.0      S  Biggin  2016-04-02       2.5
# 2  Abbotsford      3  house  1465000.0     SP  Biggin  2017-04-03       2.5
# 3  Abbotsford      3  house   850000.0     PI  Biggin  2017-04-03       2.5
# 4  Abbotsford      4  house  1600000.0     VB  Nelson  2016-04-06       2.5
#
#    Postcode  Bedroom  ...  Longtitude             Regionname  Propertycount  \
# 0      3067        2  ...    144.9984  Northern Metropolitan           4019
# 1      3067        2  ...    144.9934  Northern Metropolitan           4019
# 2      3067        3  ...    144.9944  Northern Metropolitan           4019
# 3      3067        3  ...    144.9969  Northern Metropolitan           4019
# 4      3067        3  ...    144.9941  Northern Metropolitan           4019
#
# ...

# %%
melb_data_fe['Date']=pd.to_datetime(melb_data_fe['Date']).dt.quarter

# %%
melb_data_fe['Date'].value_counts()
# Out:
# Date
# 3    4873
# 2    4359
# 4    2329
# 1    2019
# Name: count, dtype: int64

# %%
display(melb_data_fe.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  object
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  object
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  object
#  5   SellerG          13580 non-null  object
#  6   Date             13580 non-null  int32
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  object
#  15  Lattitude        13580 non-null  float64
# ...

# %%
# создаём пустой список
unique_list = []
# пробегаемся по именам столбцов в таблице
for col in melb_data_fe.columns:
    # создаём кортеж (имя столбца, число уникальных значений)
    item = (col, melb_data_fe[col].nunique(),melb_data_fe[col].dtypes) 
    # добавляем кортеж в список
    unique_list.append(item) 
# создаём вспомогательную таблицу и сортируем её
unique_counts = pd.DataFrame(
    unique_list,
    columns=['Column_Name', 'Num_Unique', 'Type']
).sort_values(by='Num_Unique',  ignore_index=True)
# выводим её на экран
display(unique_counts)
# Out:
#         Column_Name  Num_Unique     Type
# 0           Weekend           2    int64
# 1              Type           3   object
# 2              Date           4    int32
# 3            Method           5   object
# 4       WeekdaySale           7    int64
# 5        Regionname           8   object
# 6             Rooms           9    int64
# 7          Bathroom           9    int64
# 8               Car          11    int64
# 9        StreetType          11   object
# 10        MonthSale          12    int64
# 11          Bedroom          12    int64
# 12      CouncilArea          33   object
# 13          SellerG          50   object
# 14           Suburb         120   object
# 15      AgeBuilding         152    int64
# 16         Postcode         198    int64
# 17         Distance         202  float64
# 18    Propertycount         311    int64
# 19     BuildingArea         602  float64
# 20  MeanRoomsSquare        1275  float64
# 21         Landsize        1448  float64
# ...

# %%
cols_to_exclude = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car'] # список столбцов, которые мы не берём во внимание
max_unique_count = 150 # задаём максимальное число уникальных категорий
for col in melb_data_fe.columns: # цикл по именам столбцов
    if melb_data_fe[col].nunique() < max_unique_count and col not in cols_to_exclude: # проверяем условие
        melb_data_fe[col] = melb_data_fe[col].astype('category') # преобразуем тип столбца
display(melb_data_fe.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  category
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  int32
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
# ...

# %%
melb_data_fe.sort_values(by='Price').head(10)
# Out:
#                Suburb  Rooms   Type     Price Method        SellerG  Date  \
# 2652        Footscray      1   unit   85000.0     PI        Burnham     1
# 1805            other      4  house  131000.0     PI          other     1
# 7303           Albion      1   unit  145000.0     PI         Biggin     2
# 1927           Coburg      4  house  145000.0     PI         Jellis     2
# 7940         Hawthorn      1   unit  160000.0     VB            HAR     3
# 12666       Brunswick      1   unit  170000.0     VB         Nelson     3
# 8811        Footscray      1   unit  170000.0     PI        Burnham     1
# 8504   West Footscray      1   unit  185000.0     PI            Jas     2
# 7293           Albion      1   unit  185000.0      S  hockingstuart     3
# 7305           Albion      2   unit  190000.0     SP        Burnham     3
#
#        Distance  Postcode  Bedroom  ...  Longtitude             Regionname  \
# 2652        6.4      3011        1  ...   144.89000   Western Metropolitan
# ...

# %%
melb_data_fe.sort_values(by='Date', ascending=False)
# Out:
#               Suburb  Rooms       Type      Price Method        SellerG  Date  \
# 1589      Camberwell      3      house  1780000.0      S      Fletchers     4
# 5810        St Kilda      1       unit   420000.0     SP          other     4
# 5812        St Kilda      4      house  1900000.0     PI          other     4
# 4170       Moorabbin      3  townhouse   910000.0      S  hockingstuart     4
# 4169       Moorabbin      4      house  1016000.0      S         Buxton     4
# ...              ...    ...        ...        ...    ...            ...   ...
# 8792  Doncaster East      6      house  1856000.0     SP          Barry     1
# 8793           other      7      house  2705000.0      S            Ray     1
# 8794           other      3      house   530500.0      S     Buckingham     1
# 8795           other      3      house   975000.0      S          other     1
# 6790  Brunswick East      2       unit   390000.0     PI          other     1
#
# ...

# %%
melb_data_fe.sort_values(by=['Distance', 'Price']).loc[::10, ['Distance', 'Price']]
# Out:
#        Distance      Price
# 11428       0.0   387000.0
# 10512       0.7   600000.0
# 5727        1.2   485000.0
# 8671        1.2   595000.0
# 5736        1.2   740000.0
# ...         ...        ...
# 12011      38.0   680000.0
# 10673      38.0   810000.0
# 13429      38.0  1155000.0
# 11102      41.0   650000.0
# 12728      45.9   650000.0
#
# [1358 rows x 2 columns]

# %%
melb_data_fe.sort_values(by=['Price','Distance']).loc[::10, ['Price','Distance']]
# Out:
#            Price  Distance
# 2652     85000.0       6.4
# 7116    200000.0       7.8
# 5206    220000.0      11.2
# 7240    241000.0       8.2
# 2898    250000.0      13.0
# ...          ...       ...
# 13341  4060000.0       6.3
# 8591   4275000.0       1.5
# 1094   4700000.0      11.2
# 5801   5046000.0       6.1
# 251    5525000.0       6.3
#
# [1358 rows x 2 columns]

# %%
mask1 = melb_data_fe['AreaRatio'] < -0.8
mask2 = melb_data_fe['Type'] == 'townhouse'
mask3 = melb_data_fe['SellerG'] == 'McGrath'
melb_data_fe[mask1 & mask2 & mask3].sort_values(
    by=['Date', 'AreaRatio'],
    ascending=[True, False],
    ignore_index=True
).loc[:, ['Date', 'AreaRatio']]
# Out:
#    Date  AreaRatio
# 0     3  -0.947368
# 1     3  -0.970874
# 2     3  -0.971831
# 3     3  -0.974922
# 4     4  -0.945946
# 5     4  -0.953608

# %%
mask1 = melb_data_fe['Rooms'] > 2
mask2 = melb_data_fe['Type'] == 'townhouse'
melb_data_fe[mask1 & mask2].sort_values(
    by=['Rooms', 'MeanRoomsSquare'],
    ascending=[True, False],
    ignore_index=True
).loc[18, ['Price']]
# Out:
# Price    1300000.0
# Name: 18, dtype: object

# %%
melb_data_fe.sort_values(by=['AreaRatio'],ascending=False).iloc[1558,:]
# Out:
# Suburb                       Elsternwick
# Rooms                                  2
# Type                               house
# Price                           716000.0
# Method                                 S
# SellerG                    hockingstuart
# Date                                   1
# Distance                             7.2
# Postcode                            3185
# Bedroom                                2
# Bathroom                               1
# Car                                    1
# Landsize                             0.0
# BuildingArea                       126.0
# CouncilArea                    Glen Eira
# Lattitude                      -37.89438
# Longtitude                     145.00851
# Regionname         Southern Metropolitan
# Propertycount                       4898
# MeanRoomsSquare                     25.2
# AreaRatio                            1.0
# MonthSale                              3
# AgeBuilding                           47
# ...

# %%
melb_data_fe.groupby('Rooms')['Price'].mean().sort_values(ascending=False)
# Out:
# Rooms
# 7     1.920700e+06
# 5     1.870260e+06
# 6     1.849366e+06
# 8     1.602750e+06
# 4     1.445282e+06
# 3     1.076081e+06
# 10    9.000000e+05
# 2     7.750812e+05
# 1     4.338245e+05
# Name: Price, dtype: float64

# %%
melb_data_fe.groupby('Regionname')['Longtitude'].std().sort_values(ascending=False)
# Out:
# C:\Users\pavel\AppData\Local\Temp\ipykernel_15036\3384848318.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_data_fe.groupby('Regionname')['Longtitude'].std().sort_values(ascending=False)
# Regionname
# Northern Victoria             0.307344
# Eastern Victoria              0.084090
# Eastern Metropolitan          0.069711
# South-Eastern Metropolitan    0.057107
# Western Metropolitan          0.056490
# Southern Metropolitan         0.043007
# Northern Metropolitan         0.041691
# Western Victoria              0.026341
# Name: Longtitude, dtype: float64

# %%
melb_data_fe['Date']=pd.to_datetime(melb_data_fe['Date'])
melb_data_fe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  category
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
# ...

# %%
date2 = pd.to_datetime('2017-09-01')
date1 = pd.to_datetime('2017-05-01')
mask = (date1 <= melb_data_fe['Date']) & (melb_data_fe['Date']<= date2)
melb_data_fe[mask].groupby('SellerG')['Price'].sum().sort_values(ascending=True)
# Out:
# C:\Users\pavel\AppData\Local\Temp\ipykernel_15036\2626657288.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_data_fe[mask].groupby('SellerG')['Price'].sum().sort_values(ascending=True)
# SellerG
# Alexkarbon       0.0
# McGrath          0.0
# Miles            0.0
# Moonee           0.0
# Nelson           0.0
# Nick             0.0
# Noel             0.0
# O'Brien          0.0
# Philip           0.0
# Purplebricks     0.0
# RT               0.0
# RW               0.0
# Raine            0.0
# Ray              0.0
# Rendina          0.0
# Stockdale        0.0
# Sweeney          0.0
# Thomson          0.0
# Village          0.0
# Williams         0.0
# Woodards         0.0
# YPA              0.0
# McDonald         0.0
# Marshall         0.0
# Love             0.0
# LITTLE           0.0
# ...

# %%
date1 = pd.to_datetime('2017-05-01')
date2 = pd.to_datetime('2017-09-01')
mask = (date1 <= melb_data_fe['Date']) & (melb_data_fe['Date']<= date2)
melb_data_fe[mask].groupby('SellerG')['Price'].sum().sort_values(ascending=True)
# Out:
# C:\Users\pavel\AppData\Local\Temp\ipykernel_15036\3891338809.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_data_fe[mask].groupby('SellerG')['Price'].sum().sort_values(ascending=True)
# SellerG
# Alexkarbon       0.0
# McGrath          0.0
# Miles            0.0
# Moonee           0.0
# Nelson           0.0
# Nick             0.0
# Noel             0.0
# O'Brien          0.0
# Philip           0.0
# Purplebricks     0.0
# RT               0.0
# RW               0.0
# Raine            0.0
# Ray              0.0
# Rendina          0.0
# Stockdale        0.0
# Sweeney          0.0
# Thomson          0.0
# Village          0.0
# Williams         0.0
# Woodards         0.0
# YPA              0.0
# McDonald         0.0
# Marshall         0.0
# Love             0.0
# LITTLE           0.0
# ...

# %%
melb_data_fe.pivot_table(
    values='Price',
    index='Regionname',
    columns='Weekend',
    aggfunc='count'
)
# Out:
# Weekend                        0     1
# Regionname
# Eastern Metropolitan         447  1024
# Eastern Victoria              13    40
# Northern Metropolitan       1258  2632
# Northern Victoria             11    30
# South-Eastern Metropolitan   123   327
# Southern Metropolitan       1534  3161
# Western Metropolitan         960  1988
# Western Victoria               8    24

# %%
melb_data_fe.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
)
# Out:
#                            median                          mean              \
# Type                        house townhouse   unit        house   townhouse
# Regionname
# Eastern Metropolitan        674.0     233.5  203.0   717.422847  269.440678
# Eastern Victoria            843.0       0.0  230.0  3108.960000    0.000000
# Northern Metropolitan       459.5     134.0    0.0   619.249092  317.325733
# Northern Victoria           724.0       0.0    0.0  3355.463415    0.000000
# South-Eastern Metropolitan  630.5     240.0  199.0   664.306701  212.160000
# Southern Metropolitan       586.0     246.0    0.0   569.643881  278.858824
# Western Metropolitan        531.0     198.0   62.0   507.883406  244.560669
# Western Victoria            599.5       0.0    0.0   655.500000    0.000000
#
#
# Type                              unit
# Regionname
# Eastern Metropolitan        330.444444
# Eastern Victoria            295.333333
# Northern Metropolitan       495.026538
# ...

# %%
melb_data_fe.pivot_table(
    values='Price',
    index=['Method','Type'],
    columns='Regionname',
    aggfunc='median',
    fill_value=0
)
# Out:
# Regionname        Eastern Metropolitan  Eastern Victoria  \
# Method Type
# PI     house                 1244000.0          780000.0
#        townhouse              760000.0               0.0
#        unit                   650000.0               0.0
# S      house                 1127000.0          675000.0
#        townhouse              828000.0               0.0
#        unit                   645750.0          492000.0
# SA     house                  932500.0          950000.0
#        townhouse              807500.0               0.0
#        unit                        0.0               0.0
# SP     house                 1050000.0          672500.0
#        townhouse              910000.0               0.0
#        unit                   515000.0          400000.0
# VB     house                 1100000.0          712500.0
#        townhouse              892500.0               0.0
#        unit                   500000.0               0.0
#
# ...

# %%
pivot = melb_data_fe.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
)
pivot.columns
# Out:
# MultiIndex([('median',     'house'),
#             ('median', 'townhouse'),
#             ('median',      'unit'),
#             (  'mean',     'house'),
#             (  'mean', 'townhouse'),
#             (  'mean',      'unit')],
#            names=[None, 'Type'])

# %%
display(pivot['mean']['unit'])
# Out:
# Regionname
# Eastern Metropolitan          330.444444
# Eastern Victoria              295.333333
# Northern Metropolitan         495.026538
# Northern Victoria               0.000000
# South-Eastern Metropolitan    357.864865
# Southern Metropolitan         466.380245
# Western Metropolitan          557.637232
# Western Victoria                0.000000
# Name: unit, dtype: float64

# %%
mask = pivot['mean']['house'] < pivot['median']['house']
filtered_pivot = pivot[mask]
display(filtered_pivot)
# Out:
#                       median                        mean              \
# Type                   house townhouse  unit       house   townhouse
# Regionname
# Southern Metropolitan  586.0     246.0   0.0  569.643881  278.858824
# Western Metropolitan   531.0     198.0  62.0  507.883406  244.560669
#
#
# Type                         unit
# Regionname
# Southern Metropolitan  466.380245
# Western Metropolitan   557.637232

# %%
print(list(filtered_pivot.index))
# ['Southern Metropolitan', 'Western Metropolitan']
# Out:
# ['Southern Metropolitan', 'Western Metropolitan']

# %%
melb_data_fe.pivot_table(
    values='BuildingArea',
    index='Rooms',
    columns='Type',
    aggfunc=['median'],
    fill_value=0
)
# Out:
#       median
# Type   house townhouse   unit
# Rooms
# 1      126.0      88.0   69.5
# 2      126.0     114.0  110.0
# 3      126.0     126.0  126.0
# 4      141.0     159.5  126.0
# 5      177.0     152.0    0.0
# 6      126.0       0.0  171.0
# 7      216.5       0.0    0.0
# 8      126.0       0.0  126.0
# 10     126.0       0.0    0.0

# %%
melb_data_fe.pivot_table(
    values='Price',
    index='SellerG',
    columns='Type',
    aggfunc=['median'],
    fill_value=0
)
# Out:
#                   median
# Type               house  townhouse      unit
# SellerG
# Alexkarbon     1036250.0   935000.0  560000.0
# Barry           830000.0   727500.0  502000.0
# Bells           692500.0   430500.0  457500.0
# Biggin         1151750.0   675000.0  548000.0
# Brad            875000.0   700000.0  465000.0
# Buckingham      830000.0   820000.0  553000.0
# Burnham         922500.0        0.0  305000.0
# Buxton         1323750.0  1030000.0  670000.0
# C21             836500.0   768750.0  625500.0
# Cayzer         1505000.0  1450000.0  707500.0
# Chisholm       1520000.0   950000.0  640000.0
# Collins        1566500.0   930000.0  592000.0
# Douglas         684000.0   500000.0  494500.0
# Eview           760000.0   597500.0  602000.0
# Fletchers      1390000.0  1238000.0  653000.0
# Gary           1370000.0   993500.0  550000.0
# Greg           1330000.0   900000.0  547500.0
# HAR             695000.0        0.0  518000.0
# Harcourts       740000.0   653750.0  500000.0
# ...
